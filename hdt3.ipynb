# %%
#Parte 1-1
#¿Cuál es el tamaño en bytes de un array de 1000
#elementos de tipo booleano?
import numpy as np
a= np.array(np.arange(1000),dtype = bool)
a
y = (a.itemsize)
x=np.size(a)
v_bytes= x*y
print(f" el valor en bytes del arreglo de 1000 datos tipo booleano es de:{v_bytes}")
# Out:
#  el valor en bytes del arreglo de 1000 datos tipo booleano es de:1000

# %%
#Parte 1-2
#Cree un array cuyos elementos sean los enteros pares en
#[1,100] y en orden decreciente. Muestre los 10 últimos
#por pantalla.
t = np.arange(2,101,2)
t
t=np.sort(t)[::-1]
t[0:10]
# Out:
# array([100,  98,  96,  94,  92,  90,  88,  86,  84,  82])

# %%
#Parte 1-3a
a= np.array([2,4,5,6,0,3,7,4,8,8,5,2,1,5,6,1])
a
b=np.reshape(a,(4,4))
b[1]
# Out:
# array([0, 3, 7, 4])

# %%
#Parte 1-3b
a= np.array([2,4,5,6,0,3,7,4,8,8,5,2,1,5,6,1])
a
b=np.reshape(a,(4,4))
c=b[(0,2),0:3]
d=np.delete(c,1,1)
d
# Out:
# array([[2, 5],
#        [8, 5]])

# %%
#Parte 1-4
#Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9],
#obtenga la media aritmética de la diferencia (a-b)
a= np.array([1,4,2,7])
b= np.array([1,3,2,9])
c = a-b
c
m= np.mean(c)
m
# Out:
# -0.25

# %%
#Parte 1-5
#) Tengo valores de cordenadas (x, y) en las columnas
#del array
#1.33 4.5
#30.0 10.7
#70.2 0.5
x= np.array([1.33,30.0,70.2])
y= np.array([4.5,10.7,0.5])
r = np.array([x,y])
r
x=np.insert(x,3,37.1)
y=np.insert(y,3,-3.6)
r = np.array([x,y])
r= np.transpose(r)
r
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ],
#        [37.1 , -3.6 ]])

# %%
#parte 1-6
x= np.array([1.33,30.0,70.2])
y= np.array([4.5,10.7,0.5])
x=np.insert(x,3,[10.8,3.0])
y=np.insert(y,3,[35.8,12.0])
r = np.array([x,y])
r
# Out:
# array([[ 1.33, 30.  , 70.2 , 10.8 ,  3.  ],
#        [ 4.5 , 10.7 ,  0.5 , 35.8 , 12.  ]])

# %%
#parte2-1 ¿Cuántos Municipios tienen más de 100000 habitantes

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_csv('NucleosPoblacion.csv',sep=',')
d1=dataset[dataset['Poblacion'] >100000 ]
d1=d1['Municipio'].unique()
len(d1)
# Out:
# 62

# %%
#parte 2-2

# %%
#parte 2-2
import seaborn as sns
dataset = pd.read_csv('NucleosPoblacion.csv',sep=',')
x=dataset['Municipio']
y=dataset['Poblacion']
d1= pd.DataFrame({'Municipio':x,'Poblacion':y})
d1=d1.sort_values('Poblacion',ascending=False)
d1=d1[0:10]
sns.barplot(x='Municipio',
            y="Poblacion", data=d1,
            order=d1.sort_values('Poblacion').Municipio)

d2= pd.DataFrame({'Municipio':x,'Poblacion':y})
d3=d2.sort_values('Poblacion',ascending=False)
d3=d3[0:20]
d3
#la segunda ciudad mas poblada es Barcelona
#granda ocupa el lugar 18 con más poblacion
# Out:
#                       Municipio  Poblacion
# 355                      Madrid  3273049.0
# 623                   Barcelona  1619337.0
# 561                    Valencia   809267.0
# 492                     Sevilla   704198.0
# 591                    Zaragoza   675121.0
# 391                      Málaga   568507.0
# 420                      Murcia   441345.0
# 610                       Palma   404681.0
# 9    Las Palmas de Gran Canaria   383308.0
# 571                      Bilbao   353187.0
# 160            Alacant/Alicante   334418.0
# 254                     Córdoba   328547.0
# 565                  Valladolid   315522.0
# 135                        Vigo   297124.0
# 446                       Gijón   277198.0
# 642   L'Hospitalet de Llobregat   258642.0
# 67                     A Coruña   246047.0
# 272                     Granada   239154.0
# 170             Vitoria-Gasteiz   238247.0
# 177                   Elche/Elx   230822.0

# %%
#part3 2-3
#¿Cuántos municipios de Extremadura tienen más de 5000 habitantes?.
dataset = pd.read_csv('NucleosPoblacion.csv',sep=',')
d1= dataset[(dataset['Provincia'].isin([ 'Cáceres','Badajoz'])) & 
        (dataset['Poblacion'] > 5000)]
d1=d1['Municipio'].unique()
len(d1)
# Out:
# 14

# %%
#parte 2-4
#¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que
#pertenece y su población.
dataset = pd.read_csv('NucleosPoblacion.csv',sep=',')
df1= pd.DataFrame(dataset)
df1=df1.sort_values('Y',ascending=False)
df1=df1[0:1]
df1=df1[['Provincia','Y','Municipio']]
df1
# Out:
#     Provincia          Y Municipio
# 104      Lugo  43.625578   Viveiro

# %%
#parte 2-5 ) Obtenga la media, mediana, desviación estándar, valor
#máximo y valor mínimo de la población de los municipios de la provincia de Granada
dataset = pd.read_csv('NucleosPoblacion.csv',sep=',')
d1 = dataset[(dataset["Provincia"]=="Granada")]
d1 = d1["Poblacion"]
d1.describe()
# Out:
# count        20.000000
# mean      30217.850000
# std       50355.491715
# min       10386.000000
# 25%       13146.500000
# 50%       17526.000000
# 75%       21739.750000
# max      239154.000000
# Name: Poblacion, dtype: float64

# %%
#parte 2-6 Realice un histograma con la población de los
#Municipios para cada una de las provincias.
dataset = pd.read_csv('NucleosPoblacion.csv',sep=',')
d1 = dataset[["Poblacion","Provincia","Municipio"]]

for i in d1["Provincia"].unique():
    data = d1[d1["Provincia"] == i]
    prov = i
    data = data[["Municipio","Poblacion"]]
    
    plt.hist(data, bins=50)
    plt.title("Provincia: {}".format(prov))
    plt.xlabel("Municipios")
    plt.ylabel("Poblacion")
    plt.show()

# %%
#parte 2-7
#Seleccione al azar cincuenta municipios diferentes de entre los diponibles en el archivo. Asegúrese de que no
#se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?.
dataset = pd.read_csv('NucleosPoblacion.csv',sep=',')
d1 = dataset[["Poblacion","Municipio"]]
d1 = d1.groupby("Municipio").sum().reset_index()
d1 = d1.sample(50)  
d1.describe()
# Out:
#            Poblacion
# count      50.000000
# mean    35854.820000
# std     44824.549574
# min     10448.000000
# 25%     13009.000000
# 50%     18766.000000
# 75%     31787.000000
# max    218886.000000

# %%
#parte 2-8 Dígame los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en
#todos ellos y Madrid. No considere a Madrid en el
#análisis ya que la distancia sería cero.
dataset = pd.read_csv('NucleosPoblacion.csv',sep=',')
d1 = dataset[dataset["Municipio"]=="Madrid"]
d1 = d1[["X","Y"]]
pd.set_option('mode.chained_assignment', None)
d2 = dataset[["Municipio","X","Y"]]
d2["X2"] = d1["X"].iloc[0]
d2["Y2"] = d1["Y"].iloc[0]
d2["DistX"] =  d2["X"]-d2["X2"]
d2["DistY"] =  d2["Y"]-d2["Y2"]

d2 = d2[(d2["Municipio"]!="Madrid")]
d2 = d2[["Municipio","DistX","DistY"]]
d2 = d2.sort_values("Municipio", ascending = False).reset_index(drop = True)
d2.head(1)
# Out:
#   Municipio     DistX     DistY
# 0     Úbeda  0.332605 -2.405132

# %%
d2.tail(1)
# Out:
#     Municipio     DistX     DistY
# 850  A Coruña -4.687351  2.953496
